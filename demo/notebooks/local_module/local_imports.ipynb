# %%
import time
time.sleep(3)

# %% [markdown]
# # Local Module Imports
#
# This notebook demonstrates importing Python modules from the same directory.
# The `helpers.py` module is located alongside this notebook.

# %%
from helpers import greet, calculate_stats

# %% [markdown]
# ## Using the `greet` function

# %%
greet("Voici")

# %% [markdown]
# ## Using the `calculate_stats` function

# %%
numbers = [1, 2, 3, 4, 5, 10, 20, 30]
stats = calculate_stats(numbers)

print(f"Numbers: {numbers}")
print(f"Count: {stats['count']}")
print(f"Sum: {stats['sum']}")
print(f"Mean: {stats['mean']}")
print(f"Min: {stats['min']}")
print(f"Max: {stats['max']}")
