# %% [markdown]
# # Local Module Imports
#
# This notebook demonstrates importing a Python module from the same directory.

# %%
from data_utils import clean_column_names, filter_outliers

# %%
raw_columns = ["First Name", "Last Name", "  Email Address  "]
cleaned = clean_column_names(raw_columns)
print(f"Original: {raw_columns}")
print(f"Cleaned:  {cleaned}")

# %%
measurements = [10, 12, 11, 13, 12, 100, 11, 14, 12]  # 100 is an outlier
filtered = filter_outliers(measurements)
print(f"Original: {measurements}")
print(f"Filtered: {filtered}")
